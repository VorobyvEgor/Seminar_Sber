# %% [markdown]
# <a href="https://colab.research.google.com/github/VorobyvEgor/Seminar_Sber/blob/main/Homeworks/%D0%95%D0%B3%D0%BE%D1%80_%D0%92%D0%BE%D1%80%D0%BE%D0%B1%D1%8C%D0%B5%D0%B2_%D0%94%D0%BE%D0%BC%D0%B0%D1%88%D0%BD%D0%B5%D0%B5_%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Задание 1
#
# Написать функцию, которая принимает на вход список, на выход отдает список такого же размера. Выходной список формируется следующим образом: на i месте стоит произведение всех элементов ненулевых элементов входного списка кроме i. Необходимо это сделать как можно оптимальнее (в идеале за 2 прохода по массиву).
#
# Ввод: `[1, 2, 3]`
#
# Вывод: `[6, 3, 2]`
#
# Пояснение: `2 * 3 = 6`, `1 * 3 = 3`, `1 * 2 = 2`

# %%
x = [int(i) for i in input().split()]
result = [None for i in range(len(x))]
for i in range(len(x)):
  y = x.copy()
  y.remove(x[i])
  dev = 1
  if y.count(0) < len(y):
    for j in y:
      if j != 0:
        dev *= j
    result[i] = dev
print(result)
# Out:
# 2 0 0
# [None, 2, 2]

# %% [markdown]
# Не очень красивое решение, стоит подумать, как сделать красивее.

# %% [markdown]
# ### Задание 2
#
# При помощи только maplotlib.pyplot нарисуйте три любых вложенных фигуры(круг, овал, квадрат, ect).
# Как пример прилагается три вложенных овала, ваши фигуры должны быть с явно заданными цветами и различными стилями линий, после чего вам нужно указать заголовок вашего рисунка (придумайте название вашей фигуры):

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 2 * np.pi, 100)
plt.figure(figsize=(10, 5))
plt.plot([1, 1, 10, 10, 1], [1, 10, 10, 1, 1], 'b:')
plt.plot([1, 5.5, 10, 1], [1, 10, 1, 1], 'g--')
plt.plot(2.78*np.cos(x) + 5.5, 2.78*np.sin(x)+ 3.78, 'r-')
plt.title("Python's opportunities")
plt.axes().set_aspect(1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   import sys

# %% [markdown]
# ### Задание 3
#
# Напишите класс ежедневник. Он должен поддерживать следующий функционал:
# 1. Смена дня (можно сделать ручным режимом(то есть явно вызывается функция сменить день) или привязать к реальному времени)
# 2. Добавить задачу на определенный день
# 3. Перенести задачу с одного дня на другой
# 4. Получить задачи на сегодняшний день
# 5. Посчитать на сколько дней вперед есть запланированные задачи
#
# **NOTE:** Каждый пункт стоит одинаковое количество баллов. Балл дается за пункт, если он был реализован и было продемострирована его работа на конкретных примерах.

# %%
import datetime as dt

# %%
class Daily_planner():
  def __init__(self):
    pass

  def change_day(self):

# %%
dt.date.day
# Out:
# <attribute 'day' of 'datetime.date' objects>

# %% [markdown]
# ### Задание 4
#
# Необходимо написать функцию RGB_to_GRAY. В нее подется картинка ниже. Функция должна перевести картинку из цветного (трехканального) изображение в оттенки серого (одноканальное). При этом все элементы картики должны остаться на месте.
#
# **Подсказка:** Вам нужно сложить каналы между собой, умножив их на коэффициенты $\in (0,1)$. Наилучший результат получится если коэффициент перед голубым будет примерно в 3 раза меньше чем коэффициент перед красным и примерно в 5 раз меньше, чем коэффициент перед зеленым каналом.

# %%
import requests
from PIL import Image
import numpy as np

url = 'https://i.ibb.co/QCwHvPj/N.jpg'
raw = requests.get(url, stream=True).raw
Img=Image.open(raw)
Img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x210 at 0x7F5687A68750>

# %%
def RGB_to_GRAY(Img):
  arrImg = np.array(Img)
  return np.uint8(arrImg[:, :, 0] * 0.33 + arrImg[:, :, 1] * 0.55 + arrImg[:, :, 2] * 0.11)

# %%
gray = RGB_to_GRAY(Img)

# %%
Image.fromarray(gray)
# Out:
# <PIL.Image.Image image mode=L size=200x210 at 0x7F56877D3450>

# %% [markdown]
# ### Задание 5
#
# Необходимо написать функцию GRAY_to_BW. Функция принимает одноканальную картинку в градациях серого и возвращает черно-белую картику (значения только 0 и 255). Кроме того у функции должен быть параметр по умолчанию threshold $\in (0,255)$.
#
# Задание засчитывается, если работа функции продемострирована на картинке, полученной в прошлом пункте.
#
# **Подсказка:** Вам нужно подобрать порог threshold по которому выбудете определять -- заменить значение на 0 или на 255. То есть если значение меньше, чем threshold, то оно заменяется на 0, иначе заменяется на 255.

# %%
def GRAY_to_BW(Img, threshold = 240):
  b_w = Img.copy()
  b_w[b_w < threshold] = 0
  b_w[b_w >= threshold] = 255
  return b_w

# %%
b_w = GRAY_to_BW(gray)
Image.fromarray(b_w)
# Out:
# <PIL.Image.Image image mode=L size=200x210 at 0x7F5687789D90>

# %%
Image.fromarray(gray)
# Out:
# <PIL.Image.Image image mode=L size=200x210 at 0x7F5687789C50>

# %% [markdown]
# ### Задание 6
#
# Необходимо написать функцию, которая принимает на вход картинку в одноканале и матрицу, которая будет являться ядром свертки. Функция должна производить свертку одноканального изображения с ядром (заботиться о том, что после свертки изображение уменьшится не нужно).
#
# Задание будет зачтено, если работа функции будет продемострировано на картинке из прошлого пункта и ядре `np.array([[0, -0.5],[-0.5, 1]])`.
#
# **Подсказка**: напоминаю, что свертка -- это поэлементное умножение кусочка изображения и ядра с последующим сложением элементов получившейся матрицы и записи в ячейку новой матрицы.

# %%
kernel = np.array([[0, -0.5],[-0.5, 1]])
kernel
# Out:
# array([[ 0. , -0.5],
#        [-0.5,  1. ]])

# %%
b_w.shape
# Out:
# (210, 200)

# %%
def convolution(mat, ker):
  result = np.zeros((mat.shape[0] - ker.shape[0] + 1, mat.shape[1] - ker.shape[1] + 1))
  for i in range(0, mat.shape[0]-ker.shape[0] + 1):
    for j in range(0, mat.shape[1]-ker.shape[1] + 1):
      result[i][j] = np.sum(mat[i:i+ker.shape[0], j:j+ker.shape[1]] * ker)
  return result

# %%
con = np.uint8(convolution(b_w, kernel))

# %%
Image.fromarray(con)
# Out:
# <PIL.Image.Image image mode=L size=199x209 at 0x7F5687716690>
